# %% [markdown]
# <a href="https://colab.research.google.com/github/AjitBisht/Netflix_data_analysis/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Defining Problem Statement and
# Analysing basic metrics

# %%
df = pd.read_csv("netflix_data_analysis.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# The Given data is from NETFLIX, which is one of the most popular media and video
# streaming platform. They have over 10000 movies or tv shows available on their
# platform, as of mid-2021, they have over 222M Subscribers globally. This tabular dataset
# consists of listings of all the movies and tv shows available on Netflix, along with details
# such as - cast, directors, ratings, release year, duration, etc.

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['title'].nunique()
# Out:
# 8807

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# The Data given is of 8807 unique movies and TV
# shows, it contains 12 columns as shown above
# and all the columns are of object type except the
# "release_year" column which is of integer type

# %%
df.describe(include = 'all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
print(df['release_year'].min())
print(df['release_year'].max())
# Out:
# 1925
# 2021

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
print('Movie count: ',df[df['type'] == 'Movie']['title'].nunique())
print('TV Show count: ',df[df['type'] == 'TV Show']['title'].nunique())
# Out:
# Movie count:  6131
# TV Show count:  2676

# %%
df[df['type'] == 'TV Show']['duration'].value_counts()
# Out:
# duration
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# 13 Seasons       3
# 12 Seasons       2
# 15 Seasons       2
# 11 Seasons       2
# 17 Seasons       1
# Name: count, dtype: int64

# %%
df[df['type'] == 'Movie']['duration'].value_counts()
# Out:
# duration
# 90 min     152
# 97 min     146
# 94 min     146
# 93 min     146
# 91 min     144
#           ...
# 228 min      1
# 18 min       1
# 205 min      1
# 201 min      1
# 191 min      1
# Name: count, Length: 205, dtype: int64

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# **After Loading the data and having a first
# look into it, we can observe following
# points**

# %% [markdown]
# 1. The netflix data is of the movies and TV show released in between 1925 and 2021
# 2. There are total 8807 unique shows which include 6131 movies and 2676 TV shows
# 3. The column director, cast and country contains a lot of null values
# 4. The columns date_added, rating, and duration also contains null values but they are
# very less
# 5. We can see that there are a lot of movies/TV Shows that are produced in United
# States
# 6. Most of the TV shows that are launched has only 1 season
# 7. Highest number of Movies/TV shows released is in 2018
# 8. The number of shows released are reduced in the year 2019 - 2021. It may have
# been due to the pandemic that struck in these years

# %% [markdown]
# The country, genre, director and cast column are nested list
# so we need to clean them

# %% [markdown]
# Observations on the shape of data , Data
# Type and conversion to Category

# %% [markdown]
# **After loading the data we can observe following
# things about the shape and data type of the given
# data**

# %% [markdown]
# 1. The Data contains 12 columns, all the columns are of object type except the
# "release_year" column which is of integer type.
# 2. cast, director, country and genre has nested list which needs to be changed.
# 3. 'date_added' column needs to be changed to datetime type.
# 4. The 'type' and 'rating' columns can be converted to category type.

# %%
df['type'] = df['type'].astype('category')
df['rating'] = df['rating'].astype('category')
#df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 66 min         1
# 84 min         1
# 74 min         1
# Name: count, dtype: int64

# %%
#df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   category
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   category
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: category(2), int64(1), object(9)
# memory usage: 706.2+ KB

# %% [markdown]
# Data Cleaning : country, genre, director
# and cast column

# %% [markdown]
# Cleaning Cast Column

# %%
constraint = df['cast'].apply(lambda x: str(x).split(', ')).tolist()
df_cast = pd.DataFrame(constraint, index = df['title'])
df_cast = df_cast.stack()
df_cast = pd.DataFrame(df_cast)
df_cast.reset_index(inplace = True)
df_cast = df_cast[['title', 0]]
df_cast.columns = ['title', 'cast']
df_cast
df_cast[df_cast['cast'] == 'Rupa Bhimani']
# Out:
#                                                    title          cast
# 313                                         Chhota Bheem  Rupa Bhimani
# 708                                          Mighty Raju  Rupa Bhimani
# 3373                       Chhota Bheem - Dinosaur World  Rupa Bhimani
# 3379                        Chhota Bheem - Neeli Pahaadi  Rupa Bhimani
# 3386                               Chhota Bheem & Ganesh  Rupa Bhimani
# 3393                  Chhota Bheem & Krishna: Mayanagari  Rupa Bhimani
# 3400   Chhota Bheem & Krishna: Pataliputra- City of t...  Rupa Bhimani
# 3407                  Chhota Bheem And The Broken Amulet  Rupa Bhimani
# 3414              Chhota Bheem And The Crown of Valhalla  Rupa Bhimani
# 3421                Chhota Bheem and the Incan Adventure  Rupa Bhimani
# 3428                 Chhota Bheem and The ShiNobi Secret  Rupa Bhimani
# 3435                            Chhota Bheem Aur Hanuman  Rupa Bhimani
# ...

# %%
df['cast']
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %%
constraint
# Out:
# [['nan'],
#  ['Ama Qamata',
#   'Khosi Ngema',
#   'Gail Mabalane',
#   'Thabang Molaba',
#   'Dillon Windvogel',
#   'Natasha Thahane',
#   'Arno Greeff',
#   'Xolile Tshabalala',
#   'Getmore Sithole',
#   'Cindy Mahlangu',
#   'Ryle De Morny',
#   'Greteli Fincham',
#   'Sello Maake Ka-Ncube',
#   'Odwa Gwanya',
#   'Mekaila Mathys',
#   'Sandi Schultz',
#   'Duane Williams',
#   'Shamilla Miller',
#   'Patrick Mofokeng'],
#  ['Sami Bouajila',
#   'Tracy Gotoas',
#   'Samuel Jouy',
#   'Nabiha Akkari',
#   'Sofia Lesaffre',
#   'Salim Kechiouche',
#   'Noureddine Farihi',
#   'Geert Van Rampelberg',
#   'Bakary Diombera'],
#  ['nan'],
#  ['Mayur More',
#   'Jitendra Kumar',
#   'Ranjan Raj',
#   'Alam Khan',
#   'Ahsaas Channa',
#   'Revathi Pillai',
#   'Urvi Singh',
#   'Arun Kumar'],
#  ['Kate Siegel',
#   'Zach Gilford',
#   'Hamish Linklater',
#   'Henry Thomas',
#   'Kristin Lehman',
#   'Samantha Sloyan',
#   'Igby Rigney',
#   'Rahul Kohli',
#   'Annarah Cymone',
# ...

# %%
df_cast
# Out:
#                       title                   cast
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 64946                Zubaan       Manish Chaudhary
# 64947                Zubaan           Meghna Malik
# 64948                Zubaan          Malkeet Rauni
# 64949                Zubaan         Anita Shabdish
# 64950                Zubaan  Chittaranjan Tripathy
#
# [64951 rows x 2 columns]

# %% [markdown]
# **Cleaning director Column**

# %%
constraint = df['director'].apply(lambda x : str(x).split(', ')).tolist()
df_director = pd.DataFrame(constraint, index = df['title'])
df_director = df_director.stack()
df_director = pd.DataFrame(df_director)
df_director.reset_index(inplace = True)
df_director = df_director[['title', 0]]
df_director.columns = ['title', 'director']
df_director
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              nan
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              nan
# 4              Kota Factory              nan
# ...                     ...              ...
# 9607                 Zodiac    David Fincher
# 9608            Zombie Dumb              nan
# 9609             Zombieland  Ruben Fleischer
# 9610                   Zoom     Peter Hewitt
# 9611                 Zubaan      Mozez Singh
#
# [9612 rows x 2 columns]

# %% [markdown]
# **Cleaning country Column**

# %%
constraint = df['country'].apply(lambda x: str(x).split(', ')).tolist()
df_country = pd.DataFrame(constraint, index = df['title'])
df_country = df_country.stack()
df_country = pd.DataFrame(df_country)
df_country.reset_index(inplace = True)
df_country = df_country[['title', 0]]
df_country.columns = ['title', 'country']
df_country
# Out:
#                        title        country
# 0       Dick Johnson Is Dead  United States
# 1              Blood & Water   South Africa
# 2                  Ganglands            nan
# 3      Jailbirds New Orleans            nan
# 4               Kota Factory          India
# ...                      ...            ...
# 10840                 Zodiac  United States
# 10841            Zombie Dumb            nan
# 10842             Zombieland  United States
# 10843                   Zoom  United States
# 10844                 Zubaan          India
#
# [10845 rows x 2 columns]

# %% [markdown]
# **Cleaning genre Column**

# %%
constraint = df['listed_in'].apply(lambda x: str(x).split(', ')).tolist()
df_genre = pd.DataFrame(constraint, index = df['title'])
df_genre = df_genre.stack()
df_genre = pd.DataFrame(df_genre)
df_genre.reset_index(inplace = True)
df_genre = df_genre[['title', 0]]
df_genre.columns = ['title', 'genre']
df_genre
# Out:
#                       title                     genre
# 0      Dick Johnson Is Dead             Documentaries
# 1             Blood & Water    International TV Shows
# 2             Blood & Water                 TV Dramas
# 3             Blood & Water              TV Mysteries
# 4                 Ganglands            Crime TV Shows
# ...                     ...                       ...
# 19318                  Zoom  Children & Family Movies
# 19319                  Zoom                  Comedies
# 19320                Zubaan                    Dramas
# 19321                Zubaan      International Movies
# 19322                Zubaan          Music & Musicals
#
# [19323 rows x 2 columns]

# %%
print('df_cast : ',df_cast.shape)
print('df_country : ',df_country.shape)
print('df_director : ',df_director.shape)
print('df_genre : ',df_genre.shape)
# Out:
# df_cast :  (64951, 2)
# df_country :  (10845, 2)
# df_director :  (9612, 2)
# df_genre :  (19323, 2)

# %% [markdown]
# **We also need to remove these columns from the
# original dataset**

# %%
df_initial = df.drop(['director', 'cast', 'country', 'listed_in'], axis = 1)
df_initial
# Out:
#      show_id     type                  title          date_added  \
# 0         s1    Movie   Dick Johnson Is Dead  September 25, 2021
# 1         s2  TV Show          Blood & Water  September 24, 2021
# 2         s3  TV Show              Ganglands  September 24, 2021
# 3         s4  TV Show  Jailbirds New Orleans  September 24, 2021
# 4         s5  TV Show           Kota Factory  September 24, 2021
# ...      ...      ...                    ...                 ...
# 8802   s8803    Movie                 Zodiac   November 20, 2019
# 8803   s8804  TV Show            Zombie Dumb        July 1, 2019
# 8804   s8805    Movie             Zombieland    November 1, 2019
# 8805   s8806    Movie                   Zoom    January 11, 2020
# 8806   s8807    Movie                 Zubaan       March 2, 2019
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# ...

# %% [markdown]
# **Now we will merge all the new datasets with the original
# dataset**

# %%
dfa = df_cast.merge(df_director, on = 'title')
dfb = df_country.merge(df_genre, on = 'title')
df_final = dfa.merge(dfb, on = 'title')
df_final = df_final.merge(df_initial, on = 'title')
df_final
# Out:
#                        title                   cast         director  \
# 0       Dick Johnson Is Dead                    nan  Kirsten Johnson
# 1              Blood & Water             Ama Qamata              nan
# 2              Blood & Water             Ama Qamata              nan
# 3              Blood & Water             Ama Qamata              nan
# 4              Blood & Water            Khosi Ngema              nan
# ...                      ...                    ...              ...
# 201986                Zubaan         Anita Shabdish      Mozez Singh
# 201987                Zubaan         Anita Shabdish      Mozez Singh
# 201988                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201989                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201990                Zubaan  Chittaranjan Tripathy      Mozez Singh
#
#               country                   genre show_id     type  \
# 0       United States           Documentaries      s1    Movie
# ...

# %%
df_final.shape
# Out:
# (201991, 12)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201991 entries, 0 to 201990
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         201991 non-null  object
#  1   cast          201991 non-null  object
#  2   director      201991 non-null  object
#  3   country       201991 non-null  object
#  4   genre         201991 non-null  object
#  5   show_id       201991 non-null  object
#  6   type          201991 non-null  category
#  7   date_added    201833 non-null  object
#  8   release_year  201991 non-null  int64
#  9   rating        201924 non-null  category
#  10  duration      201988 non-null  object
#  11  description   201991 non-null  object
# dtypes: category(2), int64(1), object(9)
# memory usage: 15.8+ MB

# %% [markdown]
# **From the initial look we can see that discription column is
# not needed, also the date added is in the wrong format**

# %%
df_final.drop('description' , axis = 1 , inplace = True)

# %%
df_final
# Out:
#                        title                   cast         director  \
# 0       Dick Johnson Is Dead                    nan  Kirsten Johnson
# 1              Blood & Water             Ama Qamata              nan
# 2              Blood & Water             Ama Qamata              nan
# 3              Blood & Water             Ama Qamata              nan
# 4              Blood & Water            Khosi Ngema              nan
# ...                      ...                    ...              ...
# 201986                Zubaan         Anita Shabdish      Mozez Singh
# 201987                Zubaan         Anita Shabdish      Mozez Singh
# 201988                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201989                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201990                Zubaan  Chittaranjan Tripathy      Mozez Singh
#
#               country                   genre show_id     type  \
# 0       United States           Documentaries      s1    Movie
# ...

# %% [markdown]
# **Cleaning the duration column and converting it to integers**

# %%
df_final['duration'] = df_final['duration'].apply(lambda x: str(x).split(' ')[0])

# %%
df_final['duration']
# Out:
# 0          90
# 1           2
# 2           2
# 3           2
# 4           2
#          ...
# 201986    111
# 201987    111
# 201988    111
# 201989    111
# 201990    111
# Name: duration, Length: 201991, dtype: object

# %%
df_final[df_final['duration'] == 'nan']
# Out:
#                                        title        cast    director  \
# 126537                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 131603                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 131737  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#               country   genre show_id   type          date_added  \
# 126537  United States  Movies   s5542  Movie       April 4, 2017
# 131603  United States  Movies   s5795  Movie  September 16, 2016
# 131737  United States  Movies   s5814  Movie     August 15, 2016
#
#         release_year  rating duration
# 126537          2017  74 min      nan
# 131603          2010  84 min      nan
# 131737          2015  66 min      nan

# %%
df_final['duration'] = df_final['duration'].replace('nan', 0)

# %% [markdown]
# Non-Graphical Analysis: Value counts and
# unique attributes

# %% [markdown]
# **We can seperate the dataset into two parts, one
# for movies and other for TV shows**

# %%
df_final
# Out:
#                        title                   cast         director  \
# 0       Dick Johnson Is Dead                    nan  Kirsten Johnson
# 1              Blood & Water             Ama Qamata              nan
# 2              Blood & Water             Ama Qamata              nan
# 3              Blood & Water             Ama Qamata              nan
# 4              Blood & Water            Khosi Ngema              nan
# ...                      ...                    ...              ...
# 201986                Zubaan         Anita Shabdish      Mozez Singh
# 201987                Zubaan         Anita Shabdish      Mozez Singh
# 201988                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201989                Zubaan  Chittaranjan Tripathy      Mozez Singh
# 201990                Zubaan  Chittaranjan Tripathy      Mozez Singh
#
#               country                   genre show_id     type  \
# 0       United States           Documentaries      s1    Movie
# ...

# %%
df_movie = df_final[df_final['type'] == 'Movie']
df_show = df_final[df_final['type'] == 'TV Show']

# %%
df_show.groupby('cast')['title'].nunique()
# Out:
# cast
#  Jr.                       1
# 'Najite Dede               1
# 2 Chainz                   1
# A Boogie Wit tha Hoodie    1
# A.D. Miles                 3
#                           ..
# İştar Gökseven             1
# Şafak Başkaya              1
# Şehsuvar Aktaş             1
# Şenay Gürler               1
# Şükrü Özyıldız             1
# Name: title, Length: 14864, dtype: int64

# %%
print(df_movie['title'].nunique())
print(df_show['title'].nunique())
# Out:
# 6131
# 2676

# %%
print(df_movie['cast'].nunique())
print(df_show['cast'].nunique())
# Out:
# 25952
# 14864

# %%
print(df_movie['cast'].value_counts())
print(df_show['cast'].value_counts())
# Out:
# cast
# nan                1328
# Liam Neeson         161
# Alfred Molina       157
# John Krasinski      138
# Salma Hayek         130
#                    ...
# Heather Lawless       1
# Mary Woronov          1
# Jillian Nelson        1
# Grace Helbig          1
# Jenna Marbles         1
# Name: count, Length: 25952, dtype: int64
# cast
# nan                   818
# David Attenborough     82
# Takahiro Sakurai       56
# Yuki Kaji              45
# Ai Kayano              41
#                      ...
# Jamie Davis             1
# Marley Dias             1
# Mae Elliessa            1
# Mason Wells             1
# Zaela Rae               1
# Name: count, Length: 14864, dtype: int64

# %%
print(df_movie.groupby('cast')['title'].nunique())
print(df_show.groupby('cast')['title'].nunique())
# Out:
# cast
#  Jr.                     1
# "Riley" Lakdhar Dridi    1
# 'Najite Dede             1
# 2Mex                     1
# 4Minute                  1
#                         ..
# Şevket Çoruh             1
# Şinasi Yurtsever         3
# Şükran Ovalı             1
# Şükrü Özyıldız           1
# Ṣọpẹ́ Dìrísù             1
# Name: title, Length: 25952, dtype: int64
# cast
#  Jr.                       1
# 'Najite Dede               1
# 2 Chainz                   1
# A Boogie Wit tha Hoodie    1
# A.D. Miles                 3
#                           ..
# İştar Gökseven             1
# Şafak Başkaya              1
# Şehsuvar Aktaş             1
# Şenay Gürler               1
# Şükrü Özyıldız             1
# Name: title, Length: 14864, dtype: int64

# %%
print(df_movie['director'].nunique())
print(df_show['director'].nunique())
# Out:
# 4778
# 300

# %%
print(df_movie['director'].value_counts())
print(df_show['director'].value_counts())
# Out:
# director
# nan                    1285
# Martin Scorsese         419
# Youssef Chahine         409
# Cathy Garcia-Molina     356
# Steven Spielberg        355
#                        ...
# Lyric R. Cabral           1
# Marina Zenovich           1
# Tyler Greco               1
# Paul Miller               1
# Anatole Litvak            1
# Name: count, Length: 4778, dtype: int64
# director
# nan                49358
# Noam Murro           189
# Thomas Astruc        160
# Houda Benyamina      104
# Alan Poul            104
#                    ...
# Jill Bauer             1
# Vanessa Roth           1
# Michael Simon          1
# Sharon Grimberg        1
# Garrett Bradley        1
# Name: count, Length: 300, dtype: int64

# %%
print(df_movie['country'].nunique())
print(df_show['country'].nunique())
# Out:
# 123
# 67

# %%
print(df_movie['country'].value_counts())
print(df_show['country'].value_counts())
# Out:
# country
# United States     45816
# India             21411
# United Kingdom     8560
# France             6607
# nan                6199
#                   ...
# Botswana              2
# United States,        1
# Nicaragua             1
# Kazakhstan            1
# Uganda                1
# Name: count, Length: 123, dtype: int64
# country
# United States     13533
# nan                5698
# Japan              5154
# United Kingdom     4385
# South Korea        3754
#                   ...
# Cyprus               10
#                       8
# Belarus               6
# Greece                6
# Uruguay               3
# Name: count, Length: 67, dtype: int64

# %%
print(df_movie['genre'].nunique())
print(df_show['genre'].nunique())
# Out:
# 20
# 22

# %%
print(df_movie['genre'].value_counts())
print(df_show['genre'].value_counts())
# Out:
# genre
# Dramas                      29775
# International Movies        28211
# Comedies                    20829
# Action & Adventure          12216
# Independent Movies           9834
# Children & Family Movies     9771
# Thrillers                    7107
# Romantic Movies              6412
# Horror Movies                4571
# Sci-Fi & Fantasy             4037
# Music & Musicals             3077
# Documentaries                2407
# Sports Movies                1531
# Classic Movies               1434
# Cult Movies                  1077
# Anime Features               1045
# LGBTQ Movies                  838
# Faith & Spirituality          719
# Stand-Up Comedy               540
# Movies                        412
# Name: count, dtype: int64
# genre
# International TV Shows          12845
# TV Dramas                        8942
# TV Comedies                      4963
# Crime TV Shows                   4733
# Kids' TV                         4568
# ...

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 66 min         1
# 84 min         1
# 74 min         1
# Name: count, dtype: int64

# %% [markdown]
# **After doing some analysis on the movies and TV
# show datasets we can conclude following points**

# %% [markdown]
# 1. There are total 6131 different movies and 2676 TV shows.
# 2. 25952 different cast has worked on Movies and 14864 cast has worked on TV shows.
# 3. Liam Neeson is casted in more movies then anyone else and David Attenborough is
# casted most number of times in TV show.
# 4. There are total 4778 directors that have directed movies and 300 different Directors
# that have directed TV Shows.
# 5. Martin Scorsese has directed highest number of movies while Noam Murro has
# directed highest numberof TV Shows.
# 6. Netflix has released movies in total 123 different countries and it has released TV
# Shows in 67 differentcountries.
# 7. Highest number of Movies and TV Shows are released in Unites States and India is in
# the second place or highest number of movies while Japan is in the second place for
# highest number of TV Shows. This may be due to all the anime fans out there and all
# the titles of anime present in Netflix.
# 8. Dramas, International Movies and Comedies are the three genres with highest
# number of movies available in Netflix respectively.
# 9. International TV Shows, TV Dramas and TV Comedies are the three genre with the
# highest number of TV Shows available in Netflix respectively.
# 10. Highest number of content is relaesed in 2018, 2017 and 2019 respectively.
# 11. TV-MA, TV-14 and TV-PG are the three most ratings given to the netflix movies. All
# of these ratings are given to movies and TV shows that are unsuited for childrens
# and contains adult content. It shows that these kind of content are famous in Netflix

# %% [markdown]
# **Visual Analysis - Univariate, Bivariate
# after pre-processing of the data**

# %%
df_movie.head(5)
# Out:
#                                 title             cast         director  \
# 0                Dick Johnson Is Dead              nan  Kirsten Johnson
# 159  My Little Pony: A New Generation  Vanessa Hudgens    Robert Cullen
# 160  My Little Pony: A New Generation  Vanessa Hudgens   José Luis Ucha
# 161  My Little Pony: A New Generation     Kimiko Glenn    Robert Cullen
# 162  My Little Pony: A New Generation     Kimiko Glenn   José Luis Ucha
#
#            country                     genre show_id   type  \
# 0    United States             Documentaries      s1  Movie
# 159            nan  Children & Family Movies      s7  Movie
# 160            nan  Children & Family Movies      s7  Movie
# 161            nan  Children & Family Movies      s7  Movie
# 162            nan  Children & Family Movies      s7  Movie
#
#              date_added  release_year rating duration
# 0    September 25, 2021          2020  PG-13       90
# 159  September 24, 2021          2021     PG       91
# ...

# %%
df_show.head(5)
# Out:
#            title         cast director       country                   genre  \
# 1  Blood & Water   Ama Qamata      nan  South Africa  International TV Shows
# 2  Blood & Water   Ama Qamata      nan  South Africa               TV Dramas
# 3  Blood & Water   Ama Qamata      nan  South Africa            TV Mysteries
# 4  Blood & Water  Khosi Ngema      nan  South Africa  International TV Shows
# 5  Blood & Water  Khosi Ngema      nan  South Africa               TV Dramas
#
#   show_id     type          date_added  release_year rating duration
# 1      s2  TV Show  September 24, 2021          2021  TV-MA        2
# 2      s2  TV Show  September 24, 2021          2021  TV-MA        2
# 3      s2  TV Show  September 24, 2021          2021  TV-MA        2
# 4      s2  TV Show  September 24, 2021          2021  TV-MA        2
# 5      s2  TV Show  September 24, 2021          2021  TV-MA        2

# %%
df_show['director'].describe()
# Out:
# count     56148
# unique      300
# top         nan
# freq      49358
# Name: director, dtype: object

# %%
df_show['director'].value_counts()
# Out:
# director
# nan                49358
# Noam Murro           189
# Thomas Astruc        160
# Houda Benyamina      104
# Alan Poul            104
#                    ...
# Jill Bauer             1
# Vanessa Roth           1
# Michael Simon          1
# Sharon Grimberg        1
# Garrett Bradley        1
# Name: count, Length: 300, dtype: int64

# %%
x = df['type'].value_counts().index
y = df['type'].value_counts()
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = df['type'].value_counts().index
y = [df_movie['cast'].nunique(), df_show['cast'].nunique()]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = df['type'].value_counts().index
y = [df_movie['director'].nunique(), df_show['director'].nunique()]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = df['type'].value_counts().index
y = [df_movie['country'].nunique(), df_show['country'].nunique()]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = df['type'].value_counts().index
y = [df_movie['genre'].nunique(), df_show['genre'].nunique()]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **From the above graphs we can observe that movies are
# more popular then the TV Shows in Netflix as they have
# more number of movies present in Netflix then TV Shows as
# well as their are more directors, and cast creating movies.
# Movies are also released in more countries then TV Shows.**

# %%
x1 = df_movie['genre'].value_counts().index
y1 = df_movie['genre'].value_counts()
x2 = df_show['genre'].value_counts().index
y2 = df_show['genre'].value_counts()
plt.bar(x1, y1)
plt.xticks(rotation = 90)
plt.show()
plt.bar(x2, y2)
plt.xticks(rotation = 90)
plt.show()

# %%
x = df['rating'].value_counts().index
y = df['rating'].value_counts()
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.show()

# %%
df_movie['country'].nunique()
# Out:
# 123

# %%
df_show['country'].nunique()
# Out:
# 67

# %% [markdown]
# **There are total 122 different countries where netflix has
# released a movie, but there are only 66 countries where
# netflix has released TV shows (excluding nan row)**

# %%
sns.distplot(df['release_year'])
# Out:
# <Axes: xlabel='release_year', ylabel='Density'>

# %% [markdown]
# **From the above graphs we can see that the number of
# movies and TV series released in netflix has grown
# exponentially over the past 20-30 years**

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# **From the box plot above, we can see that the majority of
# Shows released in netflix are after 2015**

# %%
sns.pairplot(df)

# %%
f, axes = plt.subplots(1, 2, figsize=(12,5))
sns.distplot(df_movie['release_year'], ax=axes[0])
sns.distplot(df_show['release_year'], ax=axes[1])
axes[0].title.set_text("Movies")
axes[1].title.set_text("TV Shows")
plt.show()

# %%
print(df_movie['release_year'].min())
print(df_movie['release_year'].max())
# Out:
# 1942
# 2021

# %%
print(df_show['release_year'].min())
print(df_show['release_year'].max())
# Out:
# 1925
# 2021

# %% [markdown]
# **From the above visual analysis, we can observe
# following things**

# %% [markdown]
# 1. Movies are more popular then the TV Shows in Netflix.
# 2. Their are more directors, and cast creating movies.
# 3. Movies are released in more countries then TV Shows
# 4. The range of the release year for movies is 1942 to 2021
# 5. The range of teh release year for TV Shows is 1925 to 2021
# 6. 25952 different cast has worked on Movies and 14864 cast has worked on TV shows.
# 7. There are total 4778 directors that have directed movies and 300 different Directors
# that have directed TV Shows.
# 8. Netflix has released movies in total 123 different countries and it has released TV
# Shows in 67 different countries.
# 9. Dramas, International Movies and Comedies are the three genres with highest
# number of movies available in Netflix respectively.
# 10. International TV Shows, TV Dramas and TV Comedies are the three genre with the
# highest number of TV Shows available in Netflix respectively.
# 11. Highest number of content is relaesed in 2018, 2017 and 2019 respectively.
# 12. TV-MA, TV-14 and TV-PG are the three most ratings given to the netflix movies. All
# of these ratings are given to movies and TV shows that are unsuited for childrens
# and contains adult content. It shows that these kind of content are famous in Netflix

# %% [markdown]
# **Missing Value & Outlier check**

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# **From the data and visualizations above, we can
# get these insights**

# %% [markdown]
# 1. The range of the Netflix data release year in between 1925 and 2021.
# 2. There are total 8807 unique shows which include 6131 movies and 2676 TV shows.
# 3. United States has produced the highest numbers of TV Shows and Movies. India is in
# 2nd place for Movies while Japan is in 2nd place for TV Shows.
# 4. Most of the TV shows that are launched has only 1 season.
# 5. Highest number of Movies/TV shows released is in 2018.
# 6. The number of shows released are reduced in the year 2019 - 2021. It may have
# been due to the pandemic that struck in these years.
# 7. There are more Movies then TV Show. Similarly cast and director are also higher for
# Movies then TV Shows.
# 8. Movies are released in more countries that TV Shows.
# 9. Most of the TV Shows and Movies are made for adult audience and are rated
# accoudingly.
# 10. International TV Shows/Movies, Dramas and Comedies are the major genre present
# in Netflix.
# 11. TV shows with at-max 3 seasons are more popular.

# %% [markdown]
# **Recommendations**

# %% [markdown]
# 1. Netflix should focus on creating more movies, that will help netflix generate more
# revenues.
# 2. A majority of content present in Netflix are focused on adults as we can see from the
# count of rating and they are doing well. So Netflix should focus on more such
# content.
# 3. Japan is the 2nd highest country to create TV Shows and this is possible due ti the
# number of Anime shows produced in Japan and they seems to be doing well, so
# Netflix should focus more on these content as well to increase the number of TV
# shows poresent in Netflix.
# 4. Netflix should focus on making TV Shows available in more countries to get more
# subscribers and increase their revenue.
# 5. International TV Shows/Movies, Dramas and Comedies are the major genre present
# in Netflix, So they can focus on these genres to increase the watchtime of
# subscribers.
# 6. TV shows with at-max 3 seasons are more popular . So Netflix should focus on them
# more and try to keep the number of seasons less then 3.
